# %%
import pandas as pd
import numpy as np
import outofplane as oop

# %%
df = pd.read_csv('data/rotation-experiment-expose-points_1.csv')

# %%
#df[df['webgazer_data'].notna()]['webgazer_data']

# %%
for d in df[df['webgazer_data'].notna()]['webgazer_data'].map(eval):
    for i in d:
      ##rightEyeTopArc = list(map(lambda x: x['point'], i['importantKeypoints']))
      importantKeypoints = i['importantKeypoints']
      print(oop.isOutOfPlane(importantKeypoints))
# Out:
# [False, False, False, False, False, True, True, True]
# [False, False, False, False, False, True, True, True]
# [False, False, False, False, False, True, True, True]
# [False, False, False, False, False, True, True, True]
# [False, False, False, False, False, True, True, True]
# [False, False, False, False, False, True, True, True]
# [False, False, False, False, False, True, True, True]
# [False, False, False, False, False, True, True, True]
# [False, False, False, False, False, True, True, True]
# [False, False, False, False, False, True, True, True]
# [False, False, False, False, False, True, True, True]
# [False, False, False, False, False, True, True, True]
# [False, False, False, False, False, True, True, True]
# [False, False, False, False, False, True, True, True]
# [False, False, False, False, False, True, True, True]
# [False, False, False, False, False, True, True, True]
# [False, False, False, False, False, True, True, True]
# ...
