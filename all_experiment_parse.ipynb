# %%
import pandas as pd
import numpy as np
import blinksear as ear
import blinksdistance as distance
import blinkscolors as colors
import json
import matplotlib.pyplot as plt
from pathlib import Path

# %%
files = Path("./data/all-experiments").glob("*.csv")
i = 0
all_subject_dist = []
all_subject_blink = []
all_subject_giro = []
for file in files:
    i = i+1
    subject_id = i
    df = pd.read_csv(file)
    df['subject_id'] = subject_id
    extracted_rows = df.iloc[0:6]
    df_dist = pd.DataFrame(extracted_rows)
    extracted_rows = df.iloc[6:19]
    df_blink = pd.DataFrame(extracted_rows)
    extracted_rows = df.iloc[19:]
    df_rot = pd.DataFrame(extracted_rows)
    all_subject_dist.append(df_dist)
    all_subject_blink.append(df_blink)
    all_subject_giro.append(df_rot)

df_rot
# Out:
#     load_time               trial_type  trial_index  time_elapsed  \
# 19        NaN  video-keyboard-response           19         39686
# 20        NaN   html-keyboard-response           20         40239
# 21        NaN  video-keyboard-response           21         42271
# 22        NaN   html-keyboard-response           22         42990
# 23        NaN  video-keyboard-response           23         43874
# 24        NaN   html-keyboard-response           24         44630
# 25        NaN  video-keyboard-response           25         45298
# 26        NaN   html-keyboard-response           26         45829
# 27        NaN  video-keyboard-response           27         46494
# 28        NaN   html-keyboard-response           28         47221
# 29        NaN  video-keyboard-response           29         48634
# 30        NaN   html-keyboard-response           30         49189
# 31        NaN  video-keyboard-response           31         49825
# 32        NaN   html-keyboard-response           32         50477
# 33        NaN  video-keyboard-response           33         51938
# 34        NaN   html-keyboard-response           34         52541
# 35        NaN   html-keyboard-response           35         54523
# 36        NaN     events-tracking-stop           36         54523
#
#    internal_node_id jspsych_start_time success  item_width_mm  item_height_mm  \
# 19         0.0-20.0                NaN     NaN            NaN             NaN
# 20         0.0-21.0                NaN     NaN            NaN             NaN
# 21         0.0-22.0                NaN     NaN            NaN             NaN
# 22         0.0-23.0                NaN     NaN            NaN             NaN
# 23         0.0-24.0                NaN     NaN            NaN             NaN
# 24         0.0-25.0                NaN     NaN            NaN             NaN
# 25         0.0-26.0                NaN     NaN            NaN             NaN
# 26         0.0-27.0                NaN     NaN            NaN             NaN
# 27         0.0-28.0                NaN     NaN            NaN             NaN
# 28         0.0-29.0                NaN     NaN            NaN             NaN
# 29         0.0-30.0                NaN     NaN            NaN             NaN
# 30         0.0-31.0                NaN     NaN            NaN             NaN
# 31         0.0-32.0                NaN     NaN            NaN             NaN
# 32         0.0-33.0                NaN     NaN            NaN             NaN
# 33         0.0-34.0                NaN     NaN            NaN             NaN
# 34         0.0-35.0                NaN     NaN            NaN             NaN
# 35         0.0-36.0                NaN     NaN            NaN             NaN
# 36         0.0-37.0                NaN     NaN            NaN             NaN
#
#     item_width_px  ...  item_width_deg  px2deg  win_width_deg  win_height_deg  \
# 19            NaN  ...             NaN     NaN            NaN             NaN
# 20            NaN  ...             NaN     NaN            NaN             NaN
# 21            NaN  ...             NaN     NaN            NaN             NaN
# 22            NaN  ...             NaN     NaN            NaN             NaN
# 23            NaN  ...             NaN     NaN            NaN             NaN
# 24            NaN  ...             NaN     NaN            NaN             NaN
# 25            NaN  ...             NaN     NaN            NaN             NaN
# 26            NaN  ...             NaN     NaN            NaN             NaN
# 27            NaN  ...             NaN     NaN            NaN             NaN
# 28            NaN  ...             NaN     NaN            NaN             NaN
# 29            NaN  ...             NaN     NaN            NaN             NaN
# 30            NaN  ...             NaN     NaN            NaN             NaN
# 31            NaN  ...             NaN     NaN            NaN             NaN
# 32            NaN  ...             NaN     NaN            NaN             NaN
# 33            NaN  ...             NaN     NaN            NaN             NaN
# 34            NaN  ...             NaN     NaN            NaN             NaN
# 35            NaN  ...             NaN     NaN            NaN             NaN
# 36            NaN  ...             NaN     NaN            NaN             NaN
#
#                                         webgazer_data  webgazer_targets  \
# 19                                                NaN               NaN
# 20  [{"x":0,"y":0,"t":10,"importantKeypoints":{"no...                {}
# 21                                                NaN               NaN
# 22  [{"x":0,"y":0,"t":10,"importantKeypoints":{"no...                {}
# 23                                                NaN               NaN
# 24  [{"x":0,"y":0,"t":6,"importantKeypoints":{"nos...                {}
# 25                                                NaN               NaN
# 26  [{"x":0,"y":0,"t":4,"importantKeypoints":{"nos...                {}
# 27                                                NaN               NaN
# 28  [{"x":0,"y":0,"t":4,"importantKeypoints":{"nos...                {}
# 29                                                NaN               NaN
# 30  [{"x":0,"y":0,"t":10,"importantKeypoints":{"no...                {}
# 31                                                NaN               NaN
# 32  [{"x":0,"y":0,"t":4,"importantKeypoints":{"nos...                {}
# 33                                                NaN               NaN
# 34  [{"x":0,"y":0,"t":5,"importantKeypoints":{"nos...                {}
# 35                                                NaN               NaN
# 36                                                NaN               NaN
#
#                                              stimulus response events  \
# 19                             ["derecha_hombro.mp4"]             NaN
# 20  Luego de girar la cabeza, presione espacio par...             NaN
# 21                                    ["derecha.mp4"]             NaN
# 22  Luego de girar la cabeza, presione espacio par...             NaN
# 23                           ["izquierda_hombro.mp4"]             NaN
# 24  Luego de girar la cabeza, presione espacio par...             NaN
# 25                                  ["izquierda.mp4"]             NaN
# 26  Luego de girar la cabeza, presione espacio par...             NaN
# 27                                     ["arriba.mp4"]             NaN
# 28  Luego de girar la cabeza, presione espacio par...             NaN
# 29                                    ["arriba2.mp4"]             NaN
# 30  Luego de girar la cabeza, presione espacio par...             NaN
# 31                                      ["abajo.mp4"]             NaN
# 32  Luego de girar la cabeza, presione espacio par...             NaN
# 33                                     ["abajo2.mp4"]             NaN
# 34  Luego de girar la cabeza, presione espacio par...             NaN
# 35  \n    <p>\n      Fin del experimento. Presione...             NaN
# 36                                                NaN      NaN     []
#
#    subject_id
# 19          1
# 20          1
# 21          1
# 22          1
# 23          1
# 24          1
# 25          1
# 26          1
# 27          1
# 28          1
# 29          1
# 30          1
# 31          1
# 32          1
# 33          1
# 34          1
# 35          1
# 36          1
#
# [18 rows x 23 columns]

# %%
output_dir = './data/all-exp-separados/'  # Change this if needed

# Save each DataFrame to a separate CSV file
for i, df in enumerate(all_subject_dist, start=1):
    filename = f"{output_dir}dataframe_dist_{i}.csv"
    df.to_csv(filename, index=False)
    print(f"Saved: {filename}")
# Out:
# Saved: ./data/all-exp-separados/dataframe_dist_1.csv

# %%
output_dir = './data/all-exp-separados/'  # Change this if needed

# Save each DataFrame to a separate CSV file
for i, df in enumerate(all_subject_blink, start=1):
    filename = f"{output_dir}dataframe_blink_{i}.csv"
    df.to_csv(filename, index=False)
    print(f"Saved: {filename}")
# Out:
# Saved: ./data/all-exp-separados/dataframe_blink_1.csv

# %%
output_dir = './data/all-exp-separados/'  # Change this if needed

# Save each DataFrame to a separate CSV file
for i, df in enumerate(all_subject_giro, start=1):
    filename = f"{output_dir}dataframe_rot_{i}.csv"
    df.to_csv(filename, index=False)
    print(f"Saved: {filename}")
# Out:
# Saved: ./data/all-exp-separados/dataframe_rot_1.csv

# %%
files = Path("./data/all-experiments").glob("*.csv")
i = 0
for file in files:
    subject_id = i
    df = pd.read_csv(file)
    df['subject_id'] = subject_id
    extracted_rows = df.iloc[0:6]
    df_dist = pd.DataFrame(extracted_rows)

df_dist.head()


all_subject = []
all_subject_dist = []
all_subject_blink = []
all_subject_giro = []

experimentslist = experiments['experiment_runs'][0:5]
##print(experimentslist[1]['status'])
for run in experimentslist:
  if run['status'] == 'Finalizado' and len(run['records']) > 0:
    subject_id = run['subject']
    ##print(subject_id)
    ##print("run['status']", run['status'])

    print(subject_id)
    print("run['status']", run['status'])
    print("end_date", run['end_date'])
    df = pd.DataFrame(eval(run['records'][-1]['data'].
                           replace('true', "True").
                           replace('false', "False").
                           replace('null', 'None')))

    df['subject_id'] = subject_id

    if df.shape[0] < 38: # Filtering data from anothe experiment
      print(df.shape)
      all_subject.append(df)
    dataLen = len(data)
    print("data len", dataLen)
    ##0-5 distance
    ##6-19 blink
    ##20-37 rotation
    ##if dataLen <38:
    df_dist = pd.DataFrame(data[0:6])
    df_dist['subject_id'] = subject_id
    all_subject_dist.append(df_dist)
    if dataLen > 6:
      df_blink = pd.DataFrame(data[6:19])
      df_blink['subject_id'] = subject_id
      all_subject_blink.append(df_blink)
      if dataLen > 21:
          df_giro = pd.DataFrame(data[19:])
          df_giro['subject_id'] = subject_id
          all_subject_giro.append(df_giro)

    
    # if len(data) < 38:
    #   print(data[0])
    #   print(data[1])
    #   print(len(data))
    #   print(data[34])
    #   if len(data) > 35:
    #     print(data[35])
    #     print(data[36])


df_all_subjects_dist = pd.concat(all_subject_dist)
df_all_subjects_blink = pd.concat(all_subject_blink)
df_all_subjects_giro = pd.concat(all_subject_giro)
# Out:
# 573970a3-b144-4425-a6dd-ea6669b67197
# run['status'] Finalizado
# end_date 2025-07-01T19:11:47.189Z
# (37, 23)
# data len 37
# {'load_time': 3731, 'trial_type': 'webgazer-init-camera', 'trial_index': 0, 'time_elapsed': 6661, 'internal_node_id': '0.0-0.0'}
# {'jspsych_start_time': '2025-01-23T20:09:38.190Z', 'trial_type': 'events-tracking-start', 'trial_index': 1, 'time_elapsed': 6661, 'internal_node_id': '0.0-1.0'}
# 37
# {'rt': 150, 'stimulus': 'Luego de girar la cabeza, presione espacio para continuar', 'response': ' ', 'trial_type': 'html-keyboard-response', 'trial_index':
, {'x': 349.57, 'y': 210.88, 'point': 255}], 'rightEyeBottomArc': [{'x': 311.69, 'y': 209.05, 'point': 463}, {'x': 314.02, 'y': 211.46, 'point': 341}, {'x': 317.9, 'y': 213.18, 'point': 256}, {'x': 324.15, 'y': 215.15, 'point': 252}, {'x': 331.85, 'y': 216.32, 'point': 253}, {'x': 339.37, 'y': 216.46, 'point': 254}, {'x': 345.79, 'y': 214.62, 'point': 339}, {'x': 349.57, 'y': 210.88, 'point': 255}], 'leftEyeTopArc': [{'x': 234.76, 'y': 208.15, 'point': 25}, {'x': 235.37, 'y': 202.91, 'point': 33}, {'x': 236.93, 'y': 202.01, 'point': 246}, {'x': 239.07, 'y': 200.82, 'point': 161}, {'x': 242.86, 'y': 199.13, 'point': 160}, {'x': 249.47, 'y': 198.12, 'point': 159}, {'x': 256.46, 'y': 198.56, 'point': 158}, {'x': 263.42, 'y': 201.37, 'point': 157}, {'x': 268.19, 'y': 205.37, 'point': 173}, {'x': 272.86, 'y': 208.75, 'point': 243}], 'leftEyeBottomArc': [{'x': 234.76, 'y': 208.15, 'point': 25}, {'x': 237.94, 'y': 211.72, 'point': 110}, {'x': 243.92, 'y': 213.99, 'point': 24}, {'x': 251.43, 'y': 214.54, 'point': 23}, {'x': 259.17, 'y': 214.06, 'point': 22}, {'x': 265.89, 'y': 212.54, 'point': 26}, {'x': 270.25, 'y': 210.97, 'point': 112}, {'x': 272.86, 'y': 208.75, 'point': 243}]}, 'dz': '46.34'}, {'x': 0, 'y': 0, 't': 71, 'importantKeypoints': {'noseX': 290.17, 'noseY': 270.39, 'topY': 140.89, 'bottomY': 350.44, 'leftEarX': 375.93, 'rightearX': 204.5, 'rightEyeTopArc': [{'x': 311.86, 'y': 209.42, 'point': 463}, {'x': 316.97, 'y': 205.92, ...
# {'rt': 156, 'stimulus': '\n    <p>\n      Fin del experimento. Presione la tecla <i>espacio</i> y espere unos segundos a\n      que la pantalla quede en blanco. Luego podra cerrar la pestaña. <br>\n      Muchas gracias por participar c:\n    </p>\n    ', 'response': ' ', 'trial_type': 'html-keyboard-response', 'trial_index': 35, 'time_elapsed': 22863, 'internal_node_id': '0.0-36.0'}
# {'events': [], 'trial_type': 'events-tracking-stop', 'trial_index': 36, 'time_elapsed': 22864, 'internal_node_id': '0.0-37.0'}
# 573970a3-b144-4425-a6dd-ea6669b67197
# run['status'] Finalizado
# end_date 2025-07-01T19:10:00.868Z
# (37, 23)
# data len 37
# {'load_time': 3731, 'trial_type': 'webgazer-init-camera', 'trial_index': 0, 'time_elapsed': 6661, 'internal_node_id': '0.0-0.0'}
# {'jspsych_start_time': '2025-01-23T20:09:38.190Z', 'trial_type': 'events-tracking-start', 'trial_index': 1, 'time_elapsed': 6661, 'internal_node_id': '0.0-1.0'}
# 37
# {'rt': 150, 'stimulus': 'Luego de girar la cabeza, presione espacio para continuar', 'response': ' ', 'trial_type': 'html-keyboard-response', 'trial_index': 34, 'time_elapsed': 22707, 'internal_node_id': '0.0-35.0', 'webgazer_data': [{'x': 0, 'y': 0, 't': 2, 'importantKeypoints': {'noseX': 290.26, 'noseY': 269.84, 'topY': 140.18, 'bottomY': 350.61, 'leftEarX': 375.91, 'rightearX': 204.37, 'rightEyeTopArc': [{'x': 311.87, 'y': 209.1, 'point': 463}, {'x': 316.88, 'y': 205.7, 'point': 398}, {'x': 322.12, 'y': 201.37, 'point': 384}, {'x': 329.28, 'y': 198.53, 'point': 385}, {'x': 336.5, 'y': 198.26, 'point': 386}, {'x': 343.26, 'y': 199.84, 'point': 387}, {'x': 346.82, 'y': 202.08, 'point': 388}, {'x': 348.85, 'y': 203.77, 'point': 466}, {'x': 350.27, 'y': 205.03, 'point': 263}, {'x': 349.74, 'y': 210.68, 'point': 255}], 'rightEyeBottomArc': [{'x': 311.87, 'y': 209.1, 'point': 463}, {'x':
 'point': 243}], 'leftEyeBottomArc': [{'x': 234.76, 'y': 208.15, 'point': 25}, {'x': 237.94, 'y': 211.72, 'point': 110}, {'x': 243.92, 'y': 213.99, 'point': 24}, {'x': 251.43, 'y': 214.54, 'point': 23}, {'x': 259.17, 'y': 214.06, 'point': 22}, {'x': 265.89, 'y': 212.54, 'point': 26}, {'x': 270.25, 'y': 210.97, 'point': 112}, {'x': 272.86, 'y': 208.75, 'point': 243}]}, 'dz': '46.34'}, {'x': 0, 'y': 0, 't': 71, 'importantKeypoints': {'noseX': 290.17, 'noseY': 270.39, 'topY': 140.89, 'bottomY': 350.44, 'leftEarX': 375.93, 'rightearX': 204.5, 'rightEyeTopArc': [{'x': 311.86, 'y': 209.42, 'point': 463}, {'x': 316.97, 'y': 205.92, ...
# {'rt': 156, 'stimulus': '\n    <p>\n      Fin del experimento. Presione la tecla <i>espacio</i> y espere unos segundos a\n      que la pantalla quede en blanco. Luego podra cerrar la pestaña. <br>\n      Muchas gracias por participar c:\n    </p>\n    ', 'response': ' ', 'trial_type': 'html-keyboard-response', 'trial_index': 35, 'time_elapsed': 22863, 'internal_node_id': '0.0-36.0'}
# {'events': [], 'trial_type': 'events-tracking-stop', 'trial_index': 36, 'time_elapsed': 22864, 'internal_node_id': '0.0-37.0'}
# fc5f3dc4-72d4-4706-9c02-bf3ab594d9c9
# run['status'] Finalizado
# end_date 2025-07-01T18:51:50.794Z
# (37, 23)
# data len 37
# {'load_time': 3731, 'trial_type': 'webgazer-init-camera', 'trial_index': 0, 'time_elapsed': 6661, 'internal_node_id': '0.0-0.0'}
# {'jspsych_start_time': '2025-01-23T20:09:38.190Z', 'trial_type': 'events-tracking-start', 'trial_index': 1, 'time_elapsed': 6661, 'internal_node_id': '0.0-1.0'}
# 37
# {'rt': 150, 'stimulus': 'Luego de girar la cabeza, presione espacio para continuar', 'response': ' ', 'trial_type': 'html-keyboard-response', 'trial_index': 34, 'time_elapsed': 22707, 'internal_node_id': '0.0-35.0', 'webgazer_data': [{'x': 0, 'y': 0, 't': 2, 'importantKeypoints': {'noseX': 290.26, 'noseY': 269.84, 'topY': 140.18, 'bottomY': 350.61, 'leftEarX': 375.91, 'rightearX': 204.37, 'rightEyeTopArc': [{'x': 311.87, 'y': 209.1, 'point': 463}, {'x': 316.88, 'y': 205.7, 'point': 398}, {'x': 322.12, 'y': 201.37, 'point': 384}, {'x': 329.28, 'y': 198.53, 'point': 385}, {'x': 336.5, 'y': 198.26, 'point': 386}, {'x': 343.26, 'y': 199.84, 'point': 387}, {'x': 346.82, 'y': 202.08, 'point': 388}, {'x': 348.85, 'y': 203.77, 'point': 466}, {'x': 350.27, 'y': 205.03, 'point': 263}, {'x': 349.74, 'y': 210.68, 'point': 255}], 'rightEyeBottomArc': [{'x': 311.87, 'y': 209.1, 'point': 463}, {'x': 314.09, 'y': 211.51, 'point': 341}, {'x': 317.97, 'y': 213.34, 'point': 256}, {'x': 324.31, 'y': 215.32, 'point': 252}, {'x': 332.01, 'y': 216.4, 'point': 253}, {'x': 339.53, 'y': 216.56, 'point': 254}, {'x': 345.95, 'y': 214.62, 'point': 339}, {'x': 349.74, 'y': 210.68, 'point': 255}], 'leftEyeTopArc': [{'x': 234.85, 'y': 208.06, 'point': 25}, {'x': 235.47, 'y': 202.93, 'point': 33}, {'x': 236.98, 'y': 202.03, 'point': 246}, {'x': 239.12, 'y': 200.84, 'point': 161}, {'x': 242.85, 'y': 199.26, 'point': 160}, {'x': 249.47, 'y': 198.26, 'point': 159}, {'x': 256.46, 'y': 198.71, 'point': 158}, {'x': 263.41, 'y': 201.43, 'point': 157}, {'x': 268.27, 'y': 205.44, 'point': 173}, {'x': 273.05, 'y': 208.83, 'point': 243}], 'leftEyeBottomArc': [{'x': 234
# {'rt': 156, 'stimulus': '\n    <p>\n      Fin del experimento. Presione la tecla <i>espacio</i> y espere unos segundos a\n      que la pantalla quede en blanco. Luego podra cerrar la pestaña. <br>\n      Muchas gracias por participar c:\n    </p>\n    ', 'response': ' ', 'trial_type': 'html-keyboard-response', 'trial_index': 35, 'time_elapsed': 22863, 'internal_node_id': '0.0-36.0'}
# {'events': [], 'trial_type': 'events-tracking-stop', 'trial_index': 36, 'time_elapsed': 22864, 'internal_node_id': '0.0-37.0'}

# %%
df = all_subject_dist[0]
df_wg = df[~df["webgazer_data"].isna()]
len(df_wg["webgazer_data"].iloc[0])
# Out:
# 97

# %%
def generate_webgazer_dataframe(df):
    df_webgazer = df[~df["webgazer_data"].isna()]
    dfs = []
    for row in range(len(df_webgazer)):
        data_list = df_webgazer["webgazer_data"].iloc[row]
        df_tmp = pd.DataFrame(data_list)
        df_tmp["trial"] = row + 1
        dfs.append(df_tmp)
    return pd.concat(dfs)

# %%
def generate_chinrest_dataframe(df, i):
    df_chin = df[~df["view_dist_mm"].isna()][["view_dist_mm", "trial_index", "rt"]]
    df_chin["experiment"] = i
    return df_chin

# %%
all_subject_dist

for df in all_subject_dist:
  df_webgazer = generate_webgazer_dataframe(df)

  df_virtual_chin = df[~df["view_dist_mm"].isna()]
  df_virtual_chin.loc[:, ["view_dist_centimeters"]] = (
      df[~df["view_dist_mm"].isna()]["view_dist_mm"] / 10
  )
  (
      df_virtual_chin["rt"].reset_index(drop=True),
      df_webgazer.groupby("trial")["t"].max(),
  )

  df_webgazer = df_webgazer.astype({"dz": float, "t": float})
  df_webgazer.plot(x="t", y="dz")
  plt.xlabel("time")
  plt.ylabel("dz (cms)")
  plt.xlim(0, df_webgazer["t"].max() + 500)
  plt.hlines(
      df_webgazer["dz"].mean(),
      df_webgazer["t"].min(),
      df_webgazer["t"].max(),
      color="k",
      linestyle="--",
      lw=2,
      label="dz mean",
  )
  colors = ["r", "k", "g"]
  for i, (virtual_chin_time, virtual_chin_distance) in enumerate(
      zip(df_virtual_chin["rt"], df_virtual_chin["view_dist_centimeters"])
  ):
      plt.axvline(virtual_chin_time, color="red", linestyle="--", lw=1)
      plt.scatter(
          virtual_chin_time,
          virtual_chin_distance,
          s=50,
          color=colors[i],
          label=f"virtual chin rest trial {i + 1}",
      )
      plt.ylim(
          min(df_webgazer["dz"].min(), virtual_chin_distance) - 10,
          max(virtual_chin_distance, df_webgazer["dz"].max()) + 10,
      )

  plt.title(file)
  plt.legend(loc="upper left")
  plt.show()

# %%
output_dir = './data/'  # Change this if needed

# Save each DataFrame to a separate CSV file
for i, df in enumerate(all_subject_dist, start=1):
    filename = f"{output_dir}dataframe_dist_{i}.csv"
    df.to_csv(filename, index=False)
    print(f"Saved: {filename}")
# Out:
# Saved: ./data/dataframe_dist_1.csv
# Saved: ./data/dataframe_dist_2.csv
# Saved: ./data/dataframe_dist_3.csv
